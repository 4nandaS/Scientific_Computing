# %%
# nomor 2 bagian C

import math

x = math.pi/4
cos_approximation = 1 - (x**2)/2 + (x**4)/24 + (x**6)/720
truncation_error_bound = (x**8)/5040

print("Perkiraan nilai cos(π/4): ", cos_approximation)
print("Batas kesalahan pemotongan (truncation error bound): ", truncation_error_bound)
# Out:
# Perkiraan nilai cos(π/4):  0.7077551985967004
# Batas kesalahan pemotongan (truncation error bound):  2.872688358873207e-05
